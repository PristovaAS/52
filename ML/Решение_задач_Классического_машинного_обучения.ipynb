# %% [markdown]
# <a href="https://colab.research.google.com/github/PristovaAS/Innopolis/blob/main/ML/%D0%A0%D0%B5%D1%88%D0%B5%D0%BD%D0%B8%D0%B5_%D0%B7%D0%B0%D0%B4%D0%B0%D1%87_%D0%9A%D0%BB%D0%B0%D1%81%D1%81%D0%B8%D1%87%D0%B5%D1%81%D0%BA%D0%BE%D0%B3%D0%BE_%D0%BC%D0%B0%D1%88%D0%B8%D0%BD%D0%BD%D0%BE%D0%B3%D0%BE_%D0%BE%D0%B1%D1%83%D1%87%D0%B5%D0%BD%D0%B8%D1%8F.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.metrics import *
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import LinearRegression
from sklearn.svm import LinearSVC

# %%
df = pd.read_csv('/content/drive/MyDrive/Innopolis/diabetes.csv')
df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
df1 = df.copy()
df1.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
x = df1.drop(['Outcome'], axis=1)
y = df1['Outcome']

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.25, random_state = 123)

# %%
for i in range(5, 26, 5):
  model = KNeighborsClassifier(n_neighbors = i)
  model.fit(x_train, y_train)
  predictions = model.predict(x_test)
  print(f'Model with {i} neighbors')
  print(f'Правильность (accuracy) модели: {accuracy_score(y_test, predictions)*100:.3f} \n'
      f'Точность (precision) модели: {precision_score(y_test, predictions)*100:.3f} \n'
      f'Полнота (recall) модели: {recall_score(y_test, predictions)*100:.3f} \n'
      f'F1 мера модели: {f1_score(y_test, predictions)*100:.3f} \n')
# Out:
# Model with 5 neighbors
# Правильность (accuracy) модели: 73.958
# Точность (precision) модели: 69.492
# Полнота (recall) модели: 56.164
# F1 мера модели: 62.121
#
# Model with 10 neighbors
# Правильность (accuracy) модели: 75.000
# Точность (precision) модели: 75.510
# Полнота (recall) модели: 50.685
# F1 мера модели: 60.656
#
# Model with 15 neighbors
# Правильность (accuracy) модели: 76.562
# Точность (precision) модели: 78.000
# Полнота (recall) модели: 53.425
# F1 мера модели: 63.415
#
# Model with 20 neighbors
# Правильность (accuracy) модели: 77.604
# Точность (precision) модели: 84.091
# Полнота (recall) модели: 50.685
# F1 мера модели: 63.248
#
# Model with 25 neighbors
# Правильность (accuracy) модели: 74.479
# Точность (precision) модели: 75.000
# Полнота (recall) модели: 49.315
# F1 мера модели: 59.504

# %%
x = df1[['SkinThickness', 'BMI']]
y = df1['Insulin']

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.4, random_state = 15)

# %%
LR = LinearRegression()
LR.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = LR.predict(x_test)

# %%
print(f'Правильность (accuracy) модели: {LR.score(x_test, y_test)*100:.3f}')
# Out:
# Правильность (accuracy) модели: 13.267

# %%
print(f'a1: {LR.coef_[0]:.2f} \na2: {LR.coef_[1]:.2f}\nb: {LR.intercept_:.2f}')
# Out:
# a1: 3.37
# a2: 0.19
# b: 8.19

# %%
x = df1.drop(['Outcome'], axis=1)
y = df1['Outcome']
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.30, random_state = 11256)

# %%
SVM = LinearSVC(random_state=11256)
SVM.fit(x_train, y_train)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# LinearSVC(random_state=11256)

# %%
print(f'Правильность (accuracy) модели: {SVM.score(x_test, y_test)*100:.3f}')
# Out:
# Правильность (accuracy) модели: 72.294
