# %% [markdown]
# <a href="https://colab.research.google.com/github/PristovaAS/Innopolis/blob/main/%D0%9F%D1%80%D0%BE%D0%BC%D0%B5%D0%B6%D1%83%D1%82%D0%BE%D1%87%D0%BD%D0%B0%D1%8F%20%D0%B0%D1%82%D1%82%D0%B5%D1%81%D1%82%D0%B0%D1%86%D0%B8%D1%8F/%D0%9F%D1%80%D0%BE%D0%BC%D0%B5%D0%B6%D1%83%D1%82%D0%BE%D1%87%D0%BD%D0%B0%D1%8F_%D0%B0%D1%82%D1%82%D0%B5%D1%81%D1%82%D0%B0%D1%86%D0%B8%D1%8F.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
df = pd.read_csv("/content/drive/MyDrive/Innopolis/dataset_tk.csv")
df
# Out:
#               Unnamed: 0  Punjab  Haryana  Rajasthan  Delhi     UP  \
# 0    02/01/2019 00:00:00   119.9    130.3      234.1   85.8  313.9
# 1    03/01/2019 00:00:00   121.9    133.5      240.2   85.5  311.8
# 2    04/01/2019 00:00:00   118.8    128.2      239.8   83.5  320.7
# 3    05/01/2019 00:00:00   121.0    127.5      239.1   79.2  299.0
# 4    06/01/2019 00:00:00   121.4    132.6      240.4   76.6  286.8
# ..                   ...     ...      ...        ...    ...    ...
# 498  01/12/2020 00:00:00   130.8    126.0      220.4   77.3  322.8
# 499  02/12/2020 00:00:00   129.4    127.3      218.4   81.3  331.4
# 500  03/12/2020 00:00:00   132.1    129.7      205.6   85.6  336.7
# 501  04/12/2020 00:00:00   132.1    128.4      207.0   83.9  334.6
# 502  05/12/2020 00:00:00   120.4    111.2      201.4   83.6  287.3
#
#      Uttarakhand    HP   J&K  Chandigarh  ...  Odisha  West Bengal  Sikkim  \
# 0           40.7  30.0  52.5         5.0  ...    70.2        108.2     2.0
# ...

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Punjab', 'Haryana', 'Rajasthan', 'Delhi', 'UP',
#        'Uttarakhand', 'HP', 'J&K', 'Chandigarh', 'Chhattisgarh', 'Gujarat',
#        'MP', 'Maharashtra', 'Goa', 'DNH', 'Andhra Pradesh', 'Telangana',
#        'Karnataka', 'Kerala', 'Tamil Nadu', 'Pondy', 'Bihar', 'Jharkhand',
#        'Odisha', 'West Bengal', 'Sikkim', 'Arunachal Pradesh', 'Assam',
#        'Manipur', 'Meghalaya', 'Mizoram', 'Nagaland', 'Tripura'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 503 entries, 0 to 502
# Data columns (total 34 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Unnamed: 0         503 non-null    object
#  1   Punjab             503 non-null    float64
#  2   Haryana            503 non-null    float64
#  3   Rajasthan          503 non-null    float64
#  4   Delhi              503 non-null    float64
#  5   UP                 503 non-null    float64
#  6   Uttarakhand        503 non-null    float64
#  7   HP                 503 non-null    float64
#  8   J&K                503 non-null    float64
#  9   Chandigarh         503 non-null    float64
#  10  Chhattisgarh       503 non-null    float64
#  11  Gujarat            503 non-null    float64
#  12  MP                 503 non-null    float64
#  13  Maharashtra        503 non-null    float64
#  14  Goa                503 non-null    float64
# ...

# %%
print("Кол-во пустых ячеек в каждом стобце: \n", df.isnull().sum(), "\n")
# Out:
# Кол-во пустых ячеек в каждом стобце:
#  Unnamed: 0           0
# Punjab               0
# Haryana              0
# Rajasthan            0
# Delhi                0
# UP                   0
# Uttarakhand          0
# HP                   0
# J&K                  0
# Chandigarh           0
# Chhattisgarh         0
# Gujarat              0
# MP                   0
# Maharashtra          0
# Goa                  0
# DNH                  0
# Andhra Pradesh       0
# Telangana            0
# Karnataka            0
# Kerala               0
# Tamil Nadu           0
# Pondy                0
# Bihar                0
# Jharkhand            0
# Odisha               0
# West Bengal          0
# Sikkim               0
# Arunachal Pradesh    0
# Assam                0
# Manipur              0
# Meghalaya            0
# Mizoram              0
# Nagaland             0
# Tripura              0
# dtype: int64

# %%
df.describe()
# Out:
#            Punjab     Haryana   Rajasthan       Delhi          UP  \
# count  503.000000  503.000000  503.000000  503.000000  503.000000
# mean   141.145527  138.333598  218.443340   83.380716  314.036382
# std     56.977361   38.106593   27.421615   25.915357   66.516960
# min     56.100000   64.800000  105.800000   41.800000  186.800000
# 25%    104.000000  114.800000  205.800000   63.500000  263.650000
# 50%    118.300000  126.800000  222.900000   72.700000  290.000000
# 75%    162.500000  158.100000  237.600000  105.800000  370.550000
# max    300.000000  237.200000  278.000000  147.100000  471.800000
#
#        Uttarakhand          HP         J&K  Chandigarh  Chhattisgarh  ...  \
# count   503.000000  503.000000  503.000000  503.000000    503.000000  ...
# mean     36.157058   26.568191   44.264016    4.141551     83.877137  ...
# std       6.705108    4.807040    4.769391    1.143422     10.130427  ...
# min      16.800000   11.800000   17.800000    2.200000     37.200000  ...
# ...

# %%
df1 = df.drop(['Unnamed: 0'], axis=1)
j = 0
r = 0
c = 0
fig, axs = plt.subplots(11, 3, figsize=(15,40))
for i in df1.columns:
  axs[r, c].boxplot(df1[i])
  axs[r, c].set_title(i)
  j += 1
  c += 1
  if j % 3 == 0:
    c = 0
    r += 1

# %%
import datetime
dt = []
for i in df['Unnamed: 0']:
  a = datetime.datetime.strptime(i,"%d/%m/%Y %H:%M:%S")
  dt.append(a)
df['Unnamed: 0'] = dt

# %%
df1 = df.drop(['Unnamed: 0'], axis=1)
j = 0
r = 0
c = 0
fig, axs = plt.subplots(17, 2, figsize=(30,80))
ax.xaxis.set_major_formatter(DateFormatter('%m/%y'))
for i in df1.columns:
  axs[r, c].plot(df['Unnamed: 0'], df1[i])
  axs[r, c].set_title(i)
  j += 1
  c += 1
  if j % 2 == 0:
    c = 0
    r += 1

# %%
df['DNH'].median()
# Out:
# 18.2

# %% [markdown]
# Наблюдение 1: на графике DNH видно большое кол-во выбросов.Так же видно стабильное электропотребление на всем промежутке времени, которое в среднем составляет 18,2 MU.
#
# Наблюдение 2: на всех графиках начиная с 2020-06 наблюдается аномалия данных в виде их повторения.
